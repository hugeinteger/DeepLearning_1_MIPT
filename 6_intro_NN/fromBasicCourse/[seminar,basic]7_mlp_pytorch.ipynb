# %% [markdown]
# <img src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500,>
# <h3 style="text-align: center;"><b>Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# <h2 style="text-align: center;"><b>Многослойная сеть на PyTorch</b></h3>

# %% [markdown]
# В этом ноутбке мы научимся писать свои нейросети на фреймворке PyTorch, конкретно - рассмотрим, как написать многослойную полносвязную сеть (Fully-Connected, FC), и сравним их качество на датасете картинок MNIST.

# %% [markdown]
# <h3 style="text-align: center;"><b>Компоненты нейросети</b></h3>

# %% [markdown]
# Здесь самое время напомнить о том, какие вещи играют принципиальную роль в построении любой ***нейронной сети*** (все их мы задаём *руками*, самостоятельно):
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количество итераций обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# То, что связано с ***данными и задачей***:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# <h3 style="text-align: center;"><b>Многослойная нейронная сеть</b></h3>

# %% [markdown]
# Как можно понять из названия, многослойная нейросеть состоит из нескольких **слоёв**. Каждый слой состоит из **нейронов**. Ранее мы уже писали свой нейрон на NumPy, вот из таких нейронов и состоит ***MLP (Multi-Layer Perceptron)***. Ещё такую многослойную нейросеть, у которой каждый нейрон на предыдущем уровне соединён с нейроном на следующем уровне, называют ***Fully-Connected-сетью*** (или ***Dense-сетью***).
#
# Расмотрим их устройство более подробно:

# %% [markdown]
# * Вот так выглядит двухслойная нейросеть (первый слой - input layer - не считается, потому что это, по сути, не слой):

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net.jpeg" width=300, height=200>

# %% [markdown]
# * Так выглядит трёхслойная нейросеть:

# %% [markdown]
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" width=400>

# %% [markdown]
# .. и так далее для большего случая слоёв.

# %% [markdown]
# **Обратите внимание:** связи есть у нейронов со слоя $L_{i-1}$  и нейронов $L_{i}$, но между нейронами в одном слое связей **нет**.

# %% [markdown]
# **Входной слой** -- это данные (матрица $(n, m)$).

# %% [markdown]
# Слои, которые не являются входными или выходными, называются **скрытыми слоями (hidden layers)**.

# %% [markdown]
# При решении ***задачи регрессии*** на **выходном слое** обычно один нейрон, который возвращает предсказанные числа (для каждого объекта по числу).
#
# В случае ***задачи классификации*** на **выходном слое** обычно один нейрон, если задача бинарной классификации, и $K$ нейронов, если задача $K$-класовой классификации.

# %% [markdown]
# #### Forward pass в MLP

# %% [markdown]
# Каждый слой многослойной нейросети - это матрица весов, строки которой - это нейроны (одна строка - один нейрон), а столбцы - веса каждого нейрона (то есть одна строка - это веса одного нейрона).

# %% [markdown]
# Допустим, мы решаем задачу $K$-классовой классификации (на последнем слое $K$ нейронов). Рассмотрим, как в таком случае выглядит `forward_pass` нейросети:

# %% [markdown]
# * Вход: $$X =
# \left(
# \begin{matrix}
# x_{11} & ... & x_{1M} \\
# ... & \ddots  & ...\\
# x_{N1} & ... & x_{NM}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(N, M)$

# %% [markdown]
# * Структура сети - много слоёв, в слоях много нейронов. Первый слой (после входного) выглядит так:

# %% [markdown]
# $$ W^1 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_1} \\
# ... & \ddots  & ...\\
# w_{M1} & ... & w_{ML_1}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(M, L_1)$

# %% [markdown]
# То есть это в точности $L_1$ нейронов, каждый имеет свои собственные веса, их $M$ штук.

# %% [markdown]
# Мы помним, что нейрон - это линейное преобразование и потом нелинейная функция активации от этого преобразования. Однако в многослойных нейростеях часто отделяют `Linear` часть и `Activation`, то есть слоем считаем набор весов нейронов, а следующий слой всегда функция активации (у всех нейронов из слоя она одна и та же, обычно фреймворки не позволяют задавать конкретному нейрону в слое отличную от других нейронов в этом слое функцию активации, однако это легко сделать, объявив слой из одного нейрона).

# %% [markdown]
# * Другие слои выглядит точно так же, как первый слой. Например, у второй слой будет такой:

# %% [markdown]
# $$ W^2 =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1L_2} \\
# ... & \ddots  & ...\\
# w_{L_11} & ... & w_{L_1L_2}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_1, L_2)$

# %% [markdown]
# То есть это в точности $L_2$ нейронов, каждый имеет свои собственные веса, их $L_1$ штук.

# %% [markdown]
# * Выходной слой:
#
# Пусть в нейросети до выходного слоя идут $t$ слоёв. Тогда выходной слой имеет форму:

# %% [markdown]
# $$ W^{out} =
# \left(
# \begin{matrix}
# w_{11} & ... & w_{1K} \\
# ... & \ddots  & ...\\
# w_{L_t1} & ... & w_{L_tK}
# \end{matrix}
# \right)
# $$
#
# -- матрица $(L_t, K)$, где $L_t$ - количество нейронов в $t$-ом слое, а $K$ -- количество классов.

# %% [markdown]
# В итоге ***для `forward_pass` нам нужно просто последовтельно перемножить матрицы друг за другом, применяя после каждого умножения соответсвующую функцию активации***.

# %% [markdown]
# *Примечание*: можно думать об умножении на очередную матрицу весов как на переход в **новое признаковое пространство**. Действительно, когда подаём матрицу $X$ и умножаем на матрицу первого слоя, мы получаем матрицу размера $(N, L_1)$, то есть как будто $L_1$ "новых" признаков (построенных как линейная комбинация старых до применения функции активации, и уже как нелинейная комбинация после активации).

# %% [markdown]
# **Backward pass в MLP**

# %% [markdown]
# Обучается с помощью метода "Error Backpropagation" - ["Обратное распространение ошибки"](https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%BE%D0%B1%D1%80%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%80%D0%B0%D1%81%D0%BF%D1%80%D0%BE%D1%81%D1%82%D1%80%D0%B0%D0%BD%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BE%D1%88%D0%B8%D0%B1%D0%BA%D0%B8), принцип распространения очень похож на то, как мы обучали один нейрон - это градиентный спуск, но по "всей нейросети" сразу.

# %% [markdown]
# Backpropagation работает корректно благодаря ***chain rule*** (=правилу взятия производной сложной функции):
#
# Если $f(x) = f(g(x))$, то:
#
# $$\frac{\partial{f}}{\partial{x}} = \frac{\partial{f}}{\partial{g}} \frac{\partial{g}}{\partial{x}}$$

# %% [markdown]
# Более подробно про backpropagation можно прочитать здесь (на английском):  https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %% [markdown]
# <h3 style="text-align: center;"><b>Многослойная нейросеть на PyTorch</b></h3>

# %% [markdown]
# Ешё раз напомним про основные компоненты нейросети:
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количетсво итераций обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# То, что связано с ***данными и задачей***:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# Не будем медлить - бахнем 100 нейронов в двуслойную нейросеть (датасет - снова "Игрушка дьявола"):

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch

# %% [markdown]
# Генерация и отрисовка датасета:

# %%
# код для генерации взят из Стэнфордсокго курса:
# http://cs231n.github.io/neural-networks-case-study/#linear

N = 100
D = 2
K = 3
X = np.zeros((N * K, D))
y = np.zeros(N * K, dtype='uint8')

for j in range(K):
    ix = range(N * j,N * (j + 1))
    r = np.linspace(0.0, 1, N)
    t = np.linspace(j * 4, (j + 1) * 4,N) + np.random.randn(N) * 0.2 # theta
    X[ix] = np.c_[r * np.sin(t), r * np.cos(t)]
    y[ix] = j

# %% [markdown]
# Не забываем оборачивать данные (без этого градиенты не посчитать):

# %%
X = torch.autograd.Variable(torch.FloatTensor(X))
y = torch.autograd.Variable(torch.LongTensor(y.astype(np.int64)))

# %%
print(X.data.shape, y.data.shape)
# Out:
# torch.Size([300, 2]) torch.Size([300])

# %% [markdown]
# Сама ячейка с сеткой и обучением:

# %%
# пример взят из официального туториала: 
# https://pytorch.org/tutorials/beginner/pytorch_with_examples.html

# N - размер батча (batch_size, нужно для метода оптимизации); 
# D_in - размерность входа (количество признаков у объекта);
# H - размерность скрытых слоёв; 
# D_out - размерность выходного слоя (суть - количество классов)
N, D_in, H, D_out = 64, 2, 100, 3

# Способ 1 - Sequential
two_layer_net = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
)

# Способ 2 - сделать свой класс для сетки. Этот способ предпочтительнее
class MyNeuralNet(torch.nn.Module):
    def __init__(self, D_in, H, D_out):
        super().__init__()
        self.l1 = torch.nn.Linear(in_features=D_in, out_features=H)
        self.l12 =  torch.nn.Linear(in_features=H, out_features=H)
        self.l2 = torch.nn.Linear(in_features=H, out_features=D_out)

    def forward(self, X):
        X = torch.nn.functional.relu(self.l1(X))
        X = torch.nn.functional.relu(self.l12(X))
        return self.l2(X)

two_layer_net = MyNeuralNet(D_in, H, D_out)

# %%
loss_fn = torch.nn.CrossEntropyLoss(size_average=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
type(loss_fn)
# Out:
# torch.nn.modules.loss.CrossEntropyLoss

# %%
learning_rate = 1e-4
optimizer = torch.optim.SGD(two_layer_net.parameters(), lr=learning_rate)
for t in range(500):
    # ЗАНУЛЯЕМ!
    optimizer.zero_grad()
    # forward
    y_pred = two_layer_net(X)

    # loss
    loss = loss_fn(y_pred, y)
    print('{} {}'.format(t, loss.data))

    

    # backward
    loss.backward()

    # ОБНОВЛЯЕМ! 
    optimizer.step()
# Out:
# 0 0.6146866679191589
# 1 0.6146854162216187
# 2 0.6146844625473022
# 3 0.6146834492683411
# 4 0.6146823763847351
# 5 0.6146811842918396
# 6 0.6146799921989441
# 7 0.6146793365478516
# 8 0.6146780252456665
# 9 0.6146770119667053
# 10 0.6146758198738098
# 11 0.6146747469902039
# 12 0.6146737933158875
# 13 0.6146724820137024
# 14 0.6146716475486755
# 15 0.61467045545578
# 16 0.6146693825721741
# 17 0.6146681904792786
# 18 0.6146671772003174
# 19 0.6146661639213562
# 20 0.6146647334098816
# 21 0.6146639585494995
# 22 0.6146631240844727
# 23 0.6146617531776428
# 24 0.614660382270813
# 25 0.6146592497825623
# 26 0.6146580576896667
# 27 0.6146571636199951
# 28 0.6146560907363892
# 29 0.6146552562713623
# 30 0.6146541237831116
# 31 0.6146529912948608
# 32 0.6146517992019653
# 33 0.6146508455276489
# 34 0.6146495938301086
# 35 0.6146484613418579
# 36 0.614647626876831
# 37 0.6146465539932251
# 38 0.6146451234817505
# 39 0.6146440505981445
# 40 0.6146430373191833
# 41 0.6146420836448669
# 42 0.6146408319473267
# 43 0.6146398782730103
# 44 0.6146388053894043
# 45 0.6146377325057983
# 46 0.6146366596221924
# 47 0.6146355271339417
# 48 0.6146342754364014
# 49 0.6146335601806641
# 50 0.6146323084831238
# 51 0.6146311163902283
# 52 0.6146297454833984
# 53 0.6146286129951477
# 54 0.6146277189254761
# 55 0.6146267652511597
# 56 0.6146255135536194
# 57 0.614624559879303
# 58 0.6146236062049866
# 59 0.6146222949028015
# 60 0.6146214008331299
# 61 0.6146203875541687
# 62 0.6146193146705627
# 63 0.614618182182312
# 64 0.6146170496940613
# 65 0.6146162152290344
# 66 0.6146150827407837
# 67 0.6146137118339539
# 430 0.61421799659729
# 431 0.6142171025276184
# 432 0.6142160892486572
# 433 0.6142147779464722
# 434 0.614213764667511
# 435 0.6142125129699707
# 436 0.6142115592956543
# 437 0.6142104864120483
# 438 0.6142094135284424
# 439 0.6142085790634155
# 440 0.6142073273658752
# 441 0.6142064929008484
# 442 0.6142053008079529
# 443 0.6142042279243469
# 444 0.6142029166221619
# 445 0.6142018437385559
# 446 0.6142008304595947
# 447 0.6141995191574097
# 448 0.6141983866691589
# 449 0.6141972541809082
# 450 0.6141960024833679
# 451 0.6141951680183411
# 452 0.6141942143440247
# 453 0.6141934394836426
# 454 0.6141921281814575
# 455 0.614190936088562
# 456 0.6141896843910217
# 457 0.6141889095306396
# 458 0.6141875386238098
# 459 0.6141865849494934
# 460 0.6141855716705322
# 461 0.6141844391822815
# 462 0.6141834259033203
# 463 0.6141821146011353
# 464 0.6141810417175293
# 465 0.6141798496246338
# 466 0.6141785979270935
# 467 0.6141778230667114
# 468 0.6141770482063293
# 469 0.6141757965087891
# 470 0.6141744256019592
# 471 0.6141732335090637
# 472 0.6141722798347473
# 473 0.6141715049743652
# 474 0.6141703128814697
# 475 0.6141689419746399
# 476 0.6141681671142578
# 477 0.6141669154167175
# 478 0.6141659021377563
# 479 0.6141648888587952
# 480 0.6141636371612549
# 481 0.6141626238822937
# 482 0.6141611933708191
# 483 0.6141603589057922
# 484 0.6141591668128967
# 485 0.6141582131385803
# 486 0.6141570806503296
# 487 0.6141560077667236
# 488 0.6141550540924072
# 489 0.6141537427902222
# 490 0.6141525506973267
# 491 0.614151656627655
# 492 0.6141505241394043
# 493 0.6141495108604431
# 494 0.6141485571861267
# 495 0.6141476035118103
# 496 0.6141466498374939
# 497 0.6141455173492432
# 498 0.6141441464424133
# 499 0.6141425371170044

# %% [markdown]
# **Обратите внимание:** несмотря на то, что это задача 3-х классовой классификации и столбец $y$ нужно по-хорошему кодировать OneHotEncoding'ом, мы подали просто столбец из 0, 1 и 2 и всё отработало. Вывод - PyTorch сам делает OneHot в таком случае.

# %% [markdown]
# Проверим, насколько хороша наша сеть из 100 нейронов:

# %%
# Обратно в Numpy для отрисовки
X = X.data.numpy()
y = y.data.numpy()

# %%
# Отрисовочная магия, снова взято из:
# http://cs231n.github.io/neural-networks-case-study/#linear

h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
grid_tensor = torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])

Z = two_layer_net(torch.autograd.Variable(grid_tensor))
Z = Z.data.numpy()
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 8))

plt.contourf(xx, yy, Z, cmap=plt.cm.rainbow, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

plt.title('Игрушка дьявола', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show();

# %% [markdown]
# Качество не очень. Как же так, ведь мы использовали 100 нейронов? Разве их мало?

# %% [markdown]
# ---

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Улучшите сеть (помните про вещи, которые можно менять (см. Компоненты нейросети)). Экспериментируйте, в этом **вся суть deep learning** (и в том, чтобы рано или поздно сетка научилась экспериментировать за Вас :)

# %%
# Ваш код здесь (можно (и нужно) создавать больше ячеек)

# %% [markdown]
# ---

# %% [markdown]
# ### MNIST

# %% [markdown]
# Загрузим датасет MNIST и попробуем решить задачу классификации

# %%
# Загрузка данных, создание генератора батчей
import torchvision

# Датасет загрузится в виде PIL.Image
# Нам надо приводить картинку к torch.Tensor
# и делать нормализацию
transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.1307], [0.3081])
])

# Загрузка картинок
mnist_train_data = torchvision.datasets.MNIST(
    root='./train',
    download=True,
    train=True,
    transform=transform
)

mnist_test_data = torchvision.datasets.MNIST(
    root='./test',
    download=True,
    train=False,
    transform=transform
)

# Создание генераторов
train_batch_size = 200
test_batch_size = 1

mnist_train_dataloader = torch.utils.data.DataLoader(
    mnist_train_data,
    batch_size=train_batch_size,
    shuffle=True,
    num_workers=0
)

mnist_test_dataloader = torch.utils.data.DataLoader(
    mnist_test_data,
    batch_size=test_batch_size,
    num_workers=0
)
# Out:
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./train/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:02, 3630321.97it/s]
# Extracting ./train/MNIST/raw/train-images-idx3-ubyte.gz to ./train/MNIST/raw
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./train/MNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 56865.19it/s]
# 0it [00:00, ?it/s]
# Extracting ./train/MNIST/raw/train-labels-idx1-ubyte.gz to ./train/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./train/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:01, 892020.29it/s]
# 0it [00:00, ?it/s]
# Extracting ./train/MNIST/raw/t10k-images-idx3-ubyte.gz to ./train/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./train/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 21437.32it/s]
# 0it [00:00, ?it/s]
# Extracting ./train/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./train/MNIST/raw
# Processing...
# Done!
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./test/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:02, 3984541.95it/s]
# Extracting ./test/MNIST/raw/train-images-idx3-ubyte.gz to ./test/MNIST/raw
# 0it [00:00, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./test/MNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 56772.41it/s]
# 0it [00:00, ?it/s]
# Extracting ./test/MNIST/raw/train-labels-idx1-ubyte.gz to ./test/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./test/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:01, 987639.63it/s]
# 0it [00:00, ?it/s]
# Extracting ./test/MNIST/raw/t10k-images-idx3-ubyte.gz to ./test/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./test/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 21659.05it/s]
# Extracting ./test/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./test/MNIST/raw
# Processing...
# Done!

# %%
# Проверим, как работает генератор

for x, y in mnist_train_dataloader:
    break

# размерность x - [batch_size, n_channels, height, width]
print(x.shape, y.shape)
# print(y)
# imshow принимает numpy матрицу вида [height, width]
plt.imshow(x[0][0].numpy(), cmap='Accent_r')
plt.title(y[0].item())
plt.show()
# Out:
# torch.Size([200, 1, 28, 28]) torch.Size([200])

# %% [markdown]
# Теперь осталось построить архитектуру нейронной сети и обучить её

# %%
# YOUR CODE HERE

# %% [markdown]
# <h3 style="text-align: center;"><b>Полезные ссылки</b></h3>

# %% [markdown]
# 1). *Примеры написания нейросетей на PyTorch (офийиальные туториалы) (на английском): https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#examples
# https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html*
#
# 2). ***Один из самых подробных и полных курсов по deep learning на данный момент - это курс Стэнфордского Университета (он вообще сейчас один из лидеров в области ИИ, его выпускники работают в Google, Facebook, Amazon, Microsoft, в стартапах в Кремниевой долине):  http://cs231n.github.io/***
#
# 3). Практически исчерпывающая информация по основам нейросетей (из cs231n) (на английском):
#
# http://cs231n.github.io/neural-networks-1/,
# http://cs231n.github.io/neural-networks-2/,
# http://cs231n.github.io/neural-networks-3/,
# http://cs231n.github.io/neural-networks-case-study/#linear
#
# 4). *Хорошие статьи по основам нейросетей (на английском):  http://neuralnetworksanddeeplearning.com/chap1.html*
#
# 5). *Наглядная демонстрация того, как обучаются нейросети:  https://cs.stanford.edu/people/karpathy/convnetjs/*

# %% [markdown]
# 6). *Подробнее про backprop -- статья на Medium: https://medium.com/autonomous-agents/backpropagation-how-neural-networks-learn-complex-behaviors-9572ac161670*

# %% [markdown]
# 7). *Статья из интернет по Backprop: http://page.mi.fu-berlin.de/rojas/neural/chapter/K7.pdf*
